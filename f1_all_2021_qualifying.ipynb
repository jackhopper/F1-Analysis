# %% [markdown]
# ## Grab Data for All 2021 Qualifying Sessions
#
# I'll try to grab telemetry data for every driver's qualifying session in 2021 here, as a landing point for further analysis

# %%
#Import necessary packages
import fastf1 as ff1
from fastf1 import plotting
import numpy as np
import pandas as pd

#Enable the cache
ff1.Cache.enable_cache('C:/Users/jackh/OneDrive/Documents/Python Scripts/f1_cache')

# %%
gp_list = range(1,23)

test = ff1.get_session(2021, 5, 'Q')

# %%
#Simplified loop - where are the issues??
#Create a nested for loop that runs through the fastest qualifying lap for every driver & every qualifying session in the 2021 season. 
# #The loop starts with drivers & iterates through GPs, rather than starting with a full GP list to iterate through. 
# #I'm not sure why this works & the other way doesn't, but perhaps it is to eliminate NAs for drivers that didn't participate in a qualifying.
sessions = pd.DataFrame([])

driver_team = pd.DataFrame({'Driver':['VER', 'PER', 'HAM', 'BOT', 'LEC', 'SAI', 'RIC', 'NOR', 'ALO', 'OCO'
                                      , 'VET', 'STR', 'GAS', 'TSU', 'RUS', 'LAT', 'RAI', 'GIO', 'MSC', 'MAZ'],
                            'Team': ['Red Bull', 'Red Bull', 'Mercedes', 'Mercedes', 'Ferrari', 'Ferrari', 'McLaren', 'McLaren', 'Alpine', 'Alpine'
                                     , 'Aston Martin', 'Aston Martin', 'Alpha Tauri', 'Alpha Tauri', 'Williams', 'Williams', 'Alfa Romeo' , 'Alfa Romeo', 'Haas', 'Haas']})

driver_list = driver_team['Driver'].tolist()

df = pd.DataFrame([])

for drv in driver_list:
    
    for i in gp_list:
        quali = ff1.get_session(2021, i, 'Q')
        laps = quali.load_laps(with_telemetry=True)
        fastest = laps.pick_driver('VER').pick_fastest().get_telemetry().add_distance()
        #And add the driver variable
        fastest['Driver'] = 'VER'
        #Add ID for which Grand Prix this data is for
        fastest['GP'] = i
        fastest = pd.DataFrame(fastest)
        #Finally, add this data frame to the table for all drivers
        df = df.append(fastest)
    
    sessions = sessions.append(df)
# Out:
# core           INFO 	Loading laps for Bahrain Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Emilia Romagna Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Portuguese Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Spanish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Monaco Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Azerbaijan Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for French Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Styrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Austrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for British Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Hungarian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Belgian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Dutch Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Russian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Turkish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for United States Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Mexico City Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for São Paulo Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Qatar Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Saudi Arabian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Bahrain Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Emilia Romagna Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Portuguese Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Spanish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Monaco Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Azerbaijan Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for French Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Styrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Austrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for British Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Hungarian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Belgian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Dutch Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Russian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Turkish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for United States Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Mexico City Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for São Paulo Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Qatar Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Saudi Arabian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Bahrain Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Emilia Romagna Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Portuguese Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Spanish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Monaco Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Azerbaijan Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for French Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Styrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Austrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for British Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Hungarian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Belgian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Dutch Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Russian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Turkish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for United States Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Mexico City Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for São Paulo Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Qatar Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# ...
# core           INFO 	Loading laps for Spanish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Monaco Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Azerbaijan Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for French Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Styrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Austrian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for British Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Hungarian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# core        WARNING 	No lap data for driver 47
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Belgian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Dutch Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Italian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '88', '18', '11', '3', '99', '6', '55', '5', '31', '10']
# core           INFO 	Loading laps for Russian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Turkish Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for United States Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Mexico City Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for São Paulo Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Qatar Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Saudi Arabian Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# core           INFO 	Loading laps for Abu Dhabi Grand Prix - Qualifying [v2.1.13]
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# core           INFO 	Loaded data for 20 drivers: ['9', '16', '77', '47', '14', '33', '22', '4', '63', '44', '18', '11', '3', '99', '6', '55', '7', '5', '31', '10']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 318800 entries, 2 to 720
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   318800 non-null  datetime64[ns]
#  1   SessionTime            318800 non-null  timedelta64[ns]
#  2   DriverAhead            318800 non-null  object
#  3   DistanceToDriverAhead  318800 non-null  float64
#  4   Time                   318800 non-null  timedelta64[ns]
#  5   RPM                    318800 non-null  int64
#  6   Speed                  318800 non-null  int64
#  7   nGear                  318800 non-null  int64
#  8   Throttle               318800 non-null  int64
#  9   Brake                  318800 non-null  int64
#  10  DRS                    318800 non-null  int64
#  11  Source                 318800 non-null  object
#  12  RelativeDistance       318800 non-null  float64
#  13  Status                 318800 non-null  object
#  14  X                      318800 non-null  int64
#  15  Y                      318800 non-null  int64
#  16  Z                      318800 non-null  int64
#  17  Distance               318800 non-null  float64
#  18  Driver                 318800 non-null  object
#  19  GP                     318800 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(10), object(4), timedelta64[ns](2)
# memory usage: 51.1+ MB

# %%
#List of GPs to numbers
driver_team = pd.DataFrame({'Driver':['VER', 'PER', 'HAM', 'BOT', 'LEC', 'SAI', 'RIC', 'NOR', 'ALO', 'OCO'
                                      , 'VET', 'STR', 'GAS', 'TSU', 'RUS', 'LAT', 'RAI', 'GIO', 'MSC', 'MAZ'],
                            'Team': ['Red Bull', 'Red Bull', 'Mercedes', 'Mercedes', 'Ferrari', 'Ferrari', 'McLaren', 'McLaren', 'Alpine', 'Alpine'
                                     , 'Aston Martin', 'Aston Martin', 'Alpha Tauri', 'Alpha Tauri', 'Williams', 'Williams', 'Alfa Romeo' , 'Alfa Romeo', 'Haas', 'Haas']})

# %%
#Write output to CSV
sessions.to_csv('C:/Users/jackh/OneDrive/Documents/Python Scripts/2021_f1_qualifying_laps.csv')
